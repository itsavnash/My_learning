# %%
import pandas as pd

# %%
df =pd.read_csv("sales1_data.csv")

# %%
df.head()
# Out:
#          Date   Product  Sales Region
# 0  2023-01-01  Product3  738.0   West
# 1  2023-01-02  Product2  868.0  North
# 2  2023-01-03  Product2  554.0   West
# 3  2023-01-04  Product1  618.0  South
# 4  2023-01-05  Product3  501.0   East

# %%
df.isnull().sum()
# Out:
# Date       0
# Product    0
# Sales      6
# Region     0
# dtype: int64

# %%
df["Sales"]=df["Sales"].fillna(df["Sales"].mean())

# %%
grouped_mean =df.groupby("Product")["Sales"].agg(["mean","sum",'count'])
grouped_mean
# Out:
#                 mean     sum  count
# Product
# Product1  481.166667  2887.0      6
# Product2  661.625000  5293.0      8
# Product3  515.454545  5670.0     11

# %%
df.head()
# Out:
#          Date   Product  Sales Region
# 0  2023-01-01  Product3  738.0   West
# 1  2023-01-02  Product2  868.0  North
# 2  2023-01-03  Product2  554.0   West
# 3  2023-01-04  Product1  618.0  South
# 4  2023-01-05  Product3  501.0   East

# %%
df["Sales"] =df["Sales"].astype(int)

# %%
df = df.rename(columns={"Date":"Sale Date"})

# %%
df.head(2)
# Out:
#     Sale Date   Product  Sales Region
# 0  2023-01-01  Product3    738   West
# 1  2023-01-02  Product2    868  North

# %%
df["New Sales"] = df["Sales"].apply(lambda x : x**2)

# %%
df.head()
# Out:
#     Sale Date   Product  Sales Region  New Sales
# 0  2023-01-01  Product3    738   West     544644
# 1  2023-01-02  Product2    868  North     753424
# 2  2023-01-03  Product2    554   West     306916
# 3  2023-01-04  Product1    618  South     381924
# 4  2023-01-05  Product3    501   East     251001

# %%
grouped_mean =df.groupby(["Product","Region"])["Sales"].agg(["mean","sum","count"])
grouped_mean
# Out:
#                    mean   sum  count
# Product  Region
# Product1 South   466.60  2333      5
#          West    554.00   554      1
# Product2 North   658.00  2632      4
#          South   816.00   816      1
#          West    615.00  1845      3
# Product3 East    563.20  2816      5
#          South   309.50   619      2
#          West    558.75  2235      4

# %%
df.head()
# Out:
#     Sale Date   Product  Sales Region  New Sales
# 0  2023-01-01  Product3    738   West     544644
# 1  2023-01-02  Product2    868  North     753424
# 2  2023-01-03  Product2    554   West     306916
# 3  2023-01-04  Product1    618  South     381924
# 4  2023-01-05  Product3    501   East     251001

# %%
groupedc=df.groupby(["Region"])["Product"].count()
groupedc
# Out:
# Region
# East     5
# North    4
# South    8
# West     8
# Name: Product, dtype: int64
